# %%
import pandas as pd
# Define the URL
url = "https://raw.githubusercontent.com/Naik-Khyati/608/main/story4/input/data_cleaned_2021.csv"

# Read the selected columns into a Pandas DataFrame
columns_to_keep = ['job_title_sim', 'Avg Salary(K)', 'Job Location']
df = pd.read_csv(url, usecols=columns_to_keep)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Avg Salary(K)  742 non-null    float64
#  1   Job Location   742 non-null    object
#  2   job_title_sim  742 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 17.5+ KB

# %%
unique_job_titles = df['job_title_sim'].unique()
print(unique_job_titles)
# Out:
# ['data scientist' 'other scientist' 'analyst' 'data engineer'
#  'data analitics' 'na' 'data modeler' 'Data scientist project manager'
#  'machine learning engineer' 'director']

# %%
def assign_data_role(job_title):
    if job_title == 'data scientist':
        return 'Data Scientist'
    elif job_title == 'other scientist':
        return 'Research Scientist'
    elif job_title == 'data engineer' or job_title == 'machine learning engineer':
        return 'Data Engineer'
    elif job_title in ('analyst', 'data analitics', 'data modeler'):
        return 'Data Analyst'
    else:
        return 'Other'

df['data_role'] = df['job_title_sim'].apply(assign_data_role)

# %%
unique_data_roles = df['data_role'].unique()
print(unique_data_roles)
# Out:
# ['Data Scientist' 'Research Scientist' 'Data Analyst' 'Data Engineer'
#  'Other']

# %%
df = df[df['data_role'] != 'Other']

# %%
unique_data_roles = df['data_role'].unique()
print(unique_data_roles)
# Out:
# ['Data Scientist' 'Research Scientist' 'Data Analyst' 'Data Engineer']

# %%
df.drop(columns=['job_title_sim'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 711 entries, 0 to 741
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Avg Salary(K)  711 non-null    float64
#  1   Job Location   711 non-null    object
#  2   data_role      711 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 22.2+ KB
# <ipython-input-7-86d9e3ded54b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['job_title_sim'], inplace=True)

# %%
data_sal_url = 'https://raw.githubusercontent.com/Naik-Khyati/608/main/story4/input/data_salary.csv'
df_data_sal_url = pd.read_csv(data_sal_url)
df_data_sal_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2528 entries, 0 to 2527
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   data_role      2528 non-null   object
#  1   Job Location   2528 non-null   object
#  2   Avg Salary(K)  2528 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 59.4+ KB

# %%
# Append df_data_sal_url to df
resulting_df = pd.concat([df, df_data_sal_url], ignore_index=True)
resulting_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Avg Salary(K)  3239 non-null   float64
#  1   Job Location   3239 non-null   object
#  2   data_role      3239 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 76.0+ KB

# %%
df1=df
# Delete the original df
del df

# Rename resulting_df to df
df = resulting_df

# %%
# Pivot the DataFrame
salary_pivot = df.pivot_table(index='Job Location', columns='data_role', values='Avg Salary(K)', aggfunc='mean')

# Sort the columns by average salary
sorted_columns = salary_pivot.mean().sort_values(ascending=False).index
salary_pivot = salary_pivot[sorted_columns]

# Styling function to highlight the lowest and highest salary in each state
def highlight_lowest_and_highest_salary(s):
    is_min = s == s.min()
    is_max = s == s.max()
    return [
        f'background-color: lightcoral; color: white' if v else f'background-color: lightblue; color: white' if is_max.iloc[i] else ''
        for i, v in enumerate(is_min)
    ]

# Apply number formatting and centering
styled_salary_pivot = salary_pivot.style.format("{:.0f}").set_properties(**{'text-align': 'center'})

# Add a footnote
footnote = "Values represent average salary (in thousands $)"
styled_salary_pivot = styled_salary_pivot.set_caption(footnote)

# Style the DataFrame to highlight the lowest and highest salary in each state
styled_salary_pivot = styled_salary_pivot.apply(highlight_lowest_and_highest_salary, axis=1)

# Display the styled table
styled_salary_pivot
# Out:
# <style type="text/css">
# #T_2e3f9_row0_col0, #T_2e3f9_row1_col2, #T_2e3f9_row2_col3, #T_2e3f9_row3_col0, #T_2e3f9_row4_col0, #T_2e3f9_row5_col2, #T_2e3f9_row6_col0, #T_2e3f9_row7_col3, #T_2e3f9_row8_col0, #T_2e3f9_row9_col3, #T_2e3f9_row10_col1, #T_2e3f9_row11_col1, #T_2e3f9_row12_col0, #T_2e3f9_row13_col0, #T_2e3f9_row14_col3, #T_2e3f9_row15_col2, #T_2e3f9_row16_col1, #T_2e3f9_row17_col2, #T_2e3f9_row18_col0, #T_2e3f9_row19_col2, #T_2e3f9_row20_col1, #T_2e3f9_row21_col1, #T_2e3f9_row22_col0, #T_2e3f9_row23_col1, #T_2e3f9_row24_col0, #T_2e3f9_row25_col0, #T_2e3f9_row26_col2, #T_2e3f9_row27_col3, #T_2e3f9_row28_col3, #T_2e3f9_row29_col2, #T_2e3f9_row30_col1, #T_2e3f9_row31_col1, #T_2e3f9_row32_col0, #T_2e3f9_row33_col2, #T_2e3f9_row34_col2, #T_2e3f9_row35_col3, #T_2e3f9_row36_col0, #T_2e3f9_row37_col0, #T_2e3f9_row38_col2, #T_2e3f9_row39_col3, #T_2e3f9_row40_col1, #T_2e3f9_row41_col1, #T_2e3f9_row42_col0, #T_2e3f9_row43_col0, #T_2e3f9_row44_col0, #T_2e3f9_row45_col0, #T_2e3f9_row46_col0, #T_2e3f9_row47_col0, #T_2e3f9_row48_col3 {
#   text-align: center;
#   background-color: lightblue;
#   color: white;
# }
# #T_2e3f9_row0_col1, #T_2e3f9_row0_col2, #T_2e3f9_row1_col0, #T_2e3f9_row1_col3, #T_2e3f9_row2_col0, #T_2e3f9_row2_col1, #T_2e3f9_row3_col1, #T_2e3f9_row3_col2, #T_2e3f9_row4_col1, #T_2e3f9_row4_col3, #T_2e3f9_row5_col0, #T_2e3f9_row5_col1, #T_2e3f9_row6_col1, #T_2e3f9_row6_col2, #T_2e3f9_row7_col0, #T_2e3f9_row7_col1, #T_2e3f9_row8_col1, #T_2e3f9_row8_col2, #T_2e3f9_row9_col0, #T_2e3f9_row9_col1, #T_2e3f9_row10_col0, #T_2e3f9_row10_col2, #T_2e3f9_row11_col0, #T_2e3f9_row11_col2, #T_2e3f9_row12_col1, #T_2e3f9_row12_col2, #T_2e3f9_row13_col2, #T_2e3f9_row13_col3, #T_2e3f9_row14_col1, #T_2e3f9_row14_col2, #T_2e3f9_row15_col0, #T_2e3f9_row15_col1, #T_2e3f9_row16_col2, #T_2e3f9_row16_col3, #T_2e3f9_row17_col0, #T_2e3f9_row17_col1, #T_2e3f9_row18_col1, #T_2e3f9_row18_col3, #T_2e3f9_row19_col1, #T_2e3f9_row19_col3, #T_2e3f9_row20_col0, #T_2e3f9_row20_col2, #T_2e3f9_row21_col0, #T_2e3f9_row21_col2, #T_2e3f9_row22_col1, #T_2e3f9_row22_col2, #T_2e3f9_row23_col0, #T_2e3f9_row23_col2, #T_2e3f9_row24_col2, #T_2e3f9_row24_col3, #T_2e3f9_row25_col1, #T_2e3f9_row25_col2, #T_2e3f9_row26_col0, #T_2e3f9_row26_col1, #T_2e3f9_row27_col1, #T_2e3f9_row27_col2, #T_2e3f9_row28_col1, #T_2e3f9_row28_col2, #T_2e3f9_row29_col0, #T_2e3f9_row29_col1, #T_2e3f9_row30_col2, #T_2e3f9_row30_col3, #T_2e3f9_row31_col2, #T_2e3f9_row31_col3, #T_2e3f9_row32_col1, #T_2e3f9_row32_col2, #T_2e3f9_row33_col0, #T_2e3f9_row33_col3, #T_2e3f9_row34_col0, #T_2e3f9_row34_col3, #T_2e3f9_row35_col0, #T_2e3f9_row35_col2, #T_2e3f9_row36_col1, #T_2e3f9_row36_col2, #T_2e3f9_row37_col1, #T_2e3f9_row37_col3, #T_2e3f9_row38_col0, #T_2e3f9_row38_col1, #T_2e3f9_row39_col0, #T_2e3f9_row39_col2, #T_2e3f9_row40_col0, #T_2e3f9_row40_col2, #T_2e3f9_row41_col0, #T_2e3f9_row41_col3, #T_2e3f9_row42_col1, #T_2e3f9_row42_col2, #T_2e3f9_row43_col1, #T_2e3f9_row43_col3, #T_2e3f9_row44_col2, #T_2e3f9_row44_col3, #T_2e3f9_row45_col1, #T_2e3f9_row45_col2, #T_2e3f9_row46_col1, #T_2e3f9_row46_col3, #T_2e3f9_row47_col1, #T_2e3f9_row47_col2, #T_2e3f9_row48_col1, #T_2e3f9_row48_col2 {
#   text-align: center;
# }
# #T_2e3f9_row0_col3, #T_2e3f9_row1_col1, #T_2e3f9_row2_col2, #T_2e3f9_row3_col3, #T_2e3f9_row4_col2, #T_2e3f9_row5_col3, #T_2e3f9_row6_col3, #T_2e3f9_row7_col2, #T_2e3f9_row8_col3, #T_2e3f9_row9_col2, #T_2e3f9_row10_col3, #T_2e3f9_row11_col3, #T_2e3f9_row12_col3, #T_2e3f9_row13_col1, #T_2e3f9_row14_col0, #T_2e3f9_row15_col3, #T_2e3f9_row16_col0, #T_2e3f9_row17_col3, #T_2e3f9_row18_col2, #T_2e3f9_row19_col0, #T_2e3f9_row20_col3, #T_2e3f9_row21_col3, #T_2e3f9_row22_col3, #T_2e3f9_row23_col3, #T_2e3f9_row24_col1, #T_2e3f9_row25_col3, #T_2e3f9_row26_col3, #T_2e3f9_row27_col0, #T_2e3f9_row28_col0, #T_2e3f9_row29_col3, #T_2e3f9_row30_col0, #T_2e3f9_row31_col0, #T_2e3f9_row32_col3, #T_2e3f9_row33_col1, #T_2e3f9_row34_col1, #T_2e3f9_row35_col1, #T_2e3f9_row36_col3, #T_2e3f9_row37_col2, #T_2e3f9_row38_col3, #T_2e3f9_row39_col1, #T_2e3f9_row40_col3, #T_2e3f9_row41_col2, #T_2e3f9_row42_col3, #T_2e3f9_row43_col2, #T_2e3f9_row44_col1, #T_2e3f9_row45_col3, #T_2e3f9_row46_col2, #T_2e3f9_row47_col3, #T_2e3f9_row48_col0 {
#   text-align: center;
#   background-color: lightcoral;
#   color: white;
# }
# </style>
# <table id="T_2e3f9" class="dataframe">
#   <caption>Values represent average salary (in thousands $)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_role</th>
#       <th id="T_2e3f9_level0_col0" class="col_heading level0 col0" >Data Scientist</th>
#       <th id="T_2e3f9_level0_col1" class="col_heading level0 col1" >Data Engineer</th>
#       <th id="T_2e3f9_level0_col2" class="col_heading level0 col2" >Research Scientist</th>
#       <th id="T_2e3f9_level0_col3" class="col_heading level0 col3" >Data Analyst</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Job Location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e3f9_level0_row0" class="row_heading level0 row0" >AL</th>
#       <td id="T_2e3f9_row0_col0" class="data row0 col0" >99</td>
#       <td id="T_2e3f9_row0_col1" class="data row0 col1" >98</td>
#       <td id="T_2e3f9_row0_col2" class="data row0 col2" >96</td>
#       <td id="T_2e3f9_row0_col3" class="data row0 col3" >91</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row1" class="row_heading level0 row1" >AR</th>
#       <td id="T_2e3f9_row1_col0" class="data row1 col0" >112</td>
#       <td id="T_2e3f9_row1_col1" class="data row1 col1" >90</td>
#       <td id="T_2e3f9_row1_col2" class="data row1 col2" >112</td>
#       <td id="T_2e3f9_row1_col3" class="data row1 col3" >101</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row2" class="row_heading level0 row2" >AZ</th>
#       <td id="T_2e3f9_row2_col0" class="data row2 col0" >100</td>
#       <td id="T_2e3f9_row2_col1" class="data row2 col1" >101</td>
#       <td id="T_2e3f9_row2_col2" class="data row2 col2" >88</td>
#       <td id="T_2e3f9_row2_col3" class="data row2 col3" >103</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row3" class="row_heading level0 row3" >CA</th>
#       <td id="T_2e3f9_row3_col0" class="data row3 col0" >133</td>
#       <td id="T_2e3f9_row3_col1" class="data row3 col1" >119</td>
#       <td id="T_2e3f9_row3_col2" class="data row3 col2" >97</td>
#       <td id="T_2e3f9_row3_col3" class="data row3 col3" >90</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row4" class="row_heading level0 row4" >CO</th>
#       <td id="T_2e3f9_row4_col0" class="data row4 col0" >105</td>
#       <td id="T_2e3f9_row4_col1" class="data row4 col1" >94</td>
#       <td id="T_2e3f9_row4_col2" class="data row4 col2" >77</td>
#       <td id="T_2e3f9_row4_col3" class="data row4 col3" >102</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row5" class="row_heading level0 row5" >CT</th>
#       <td id="T_2e3f9_row5_col0" class="data row5 col0" >99</td>
#       <td id="T_2e3f9_row5_col1" class="data row5 col1" >97</td>
#       <td id="T_2e3f9_row5_col2" class="data row5 col2" >106</td>
#       <td id="T_2e3f9_row5_col3" class="data row5 col3" >89</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row6" class="row_heading level0 row6" >DC</th>
#       <td id="T_2e3f9_row6_col0" class="data row6 col0" >107</td>
#       <td id="T_2e3f9_row6_col1" class="data row6 col1" >101</td>
#       <td id="T_2e3f9_row6_col2" class="data row6 col2" >96</td>
#       <td id="T_2e3f9_row6_col3" class="data row6 col3" >92</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row7" class="row_heading level0 row7" >DE</th>
#       <td id="T_2e3f9_row7_col0" class="data row7 col0" >100</td>
#       <td id="T_2e3f9_row7_col1" class="data row7 col1" >92</td>
#       <td id="T_2e3f9_row7_col2" class="data row7 col2" >87</td>
#       <td id="T_2e3f9_row7_col3" class="data row7 col3" >112</td>
#     </tr>
#     <tr>
#       <th id="T_2e3f9_level0_row8" class="row_headi

# %%
# Define a dictionary to map full state names to regions
regions = {
    'AL': 'South',
    'AK': 'West',
    'AZ': 'West',
    'AR': 'South',
    'CA': 'West',
    'CO': 'West',
    'CT': 'Northeast',
    'DE': 'South',
    'FL': 'South',
    'GA': 'South',
    'HI': 'West',
    'ID': 'West',
    'IL': 'Midwest',
    'IN': 'Midwest',
    'IA': 'Midwest',
    'KS': 'Midwest',
    'KY': 'South',
    'LA': 'South',
    'ME': 'Northeast',
    'MD': 'Northeast',
    'MA': 'Northeast',
    'MI': 'Midwest',
    'MN': 'Midwest',
    'MS': 'South',
    'MO': 'Midwest',
    'MT': 'West',
    'NE': 'Midwest',
    'NV': 'West',
    'NH': 'Northeast',
    'NJ': 'Northeast',
    'NM': 'West',
    'NY': 'Northeast',
    'NC': 'South',
    'ND': 'Midwest',
    'OH': 'Midwest',
    'OK': 'South',
    'OR': 'West',
    'PA': 'Northeast',
    'RI': 'Northeast',
    'SC': 'South',
    'SD': 'Midwest',
    'TN': 'South',
    'TX': 'South',
    'UT': 'West',
    'VT': 'Northeast',
    'VA': 'South',
    'WA': 'West',
    'WV': 'South',
    'WI': 'Midwest',
    'WY': 'West',
    'DC': 'Northeast',
}

# Create a new column 'regions' based on state names
df['regions'] = df['Job Location'].map(regions)

# Define the consistent order of data roles for all tables
data_roles_order = ['Data Analyst', 'Data Engineer', 'Data Scientist', 'Research Scientist']

# Loop through regions and create tables
region_tables = {}

for region in regions.values():
    region_df = df[df['regions'] == region]

    # Pivot the DataFrame
    region_salary_pivot = region_df.pivot_table(index='Job Location', columns='data_role', values='Avg Salary(K)', aggfunc='mean')

    # Ensure columns are in the specified order
    region_salary_pivot = region_salary_pivot[data_roles_order]

    # Apply number formatting and centering
    styled_region_salary_pivot = region_salary_pivot.style.format("{:.0f}").set_properties(**{'text-align': 'center'})

    # Add a footnote
    footnote = f"Values represent average salary (in thousands $) in {region} region"
    styled_region_salary_pivot = styled_region_salary_pivot.set_caption(footnote)

    # Style the DataFrame to highlight the lowest and highest salary in each state
    styled_region_salary_pivot = styled_region_salary_pivot.apply(highlight_lowest_and_highest_salary, axis=1)

    # Add the styled table to the region_tables dictionary
    region_tables[region] = styled_region_salary_pivot

# Display the region-specific tables
for region, region_table in region_tables.items():
    print(f"Region: {region}")
    display(region_table)
# Out:
# Region: South
# <style type="text/css">
# #T_a9c6b_row0_col0, #T_a9c6b_row1_col1, #T_a9c6b_row2_col3, #T_a9c6b_row3_col0, #T_a9c6b_row4_col3, #T_a9c6b_row5_col0, #T_a9c6b_row6_col2, #T_a9c6b_row7_col0, #T_a9c6b_row8_col0, #T_a9c6b_row9_col1, #T_a9c6b_row10_col0, #T_a9c6b_row11_col0, #T_a9c6b_row12_col3, #T_a9c6b_row13_col3, #T_a9c6b_row14_col0 {
#   text-align: center;
#   background-color: lightcoral;
#   color: white;
# }
# #T_a9c6b_row0_col1, #T_a9c6b_row0_col3, #T_a9c6b_row1_col0, #T_a9c6b_row1_col2, #T_a9c6b_row2_col1, #T_a9c6b_row2_col2, #T_a9c6b_row3_col1, #T_a9c6b_row3_col3, #T_a9c6b_row4_col1, #T_a9c6b_row4_col2, #T_a9c6b_row5_col1, #T_a9c6b_row5_col2, #T_a9c6b_row6_col0, #T_a9c6b_row6_col3, #T_a9c6b_row7_col2, #T_a9c6b_row7_col3, #T_a9c6b_row8_col1, #T_a9c6b_row8_col3, #T_a9c6b_row9_col0, #T_a9c6b_row9_col2, #T_a9c6b_row10_col1, #T_a9c6b_row10_col2, #T_a9c6b_row11_col2, #T_a9c6b_row11_col3, #T_a9c6b_row12_col0, #T_a9c6b_row12_col2, #T_a9c6b_row13_col0, #T_a9c6b_row13_col1, #T_a9c6b_row14_col1, #T_a9c6b_row14_col3 {
#   text-align: center;
# }
# #T_a9c6b_row0_col2, #T_a9c6b_row1_col3, #T_a9c6b_row2_col0, #T_a9c6b_row3_col2, #T_a9c6b_row4_col0, #T_a9c6b_row5_col3, #T_a9c6b_row6_col1, #T_a9c6b_row7_col1, #T_a9c6b_row8_col2, #T_a9c6b_row9_col3, #T_a9c6b_row10_col3, #T_a9c6b_row11_col1, #T_a9c6b_row12_col1, #T_a9c6b_row13_col2, #T_a9c6b_row14_col2 {
#   text-align: center;
#   background-color: lightblue;
#   color: white;
# }
# </style>
# <table id="T_a9c6b" class="dataframe">
#   <caption>Values represent average salary (in thousands $) in South region</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_role</th>
#       <th id="T_a9c6b_level0_col0" class="col_heading level0 col0" >Data Analyst</th>
#       <th id="T_a9c6b_level0_col1" class="col_heading level0 col1" >Data Engineer</th>
#       <th id="T_a9c6b_level0_col2" class="col_heading level0 col2" >Data Scientist</th>
#       <th id="T_a9c6b_level0_col3" class="col_heading level0 col3" >Research Scientist</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Job Location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9c6b_level0_row0" class="row_heading level0 row0" >AL</th>
#       <td id="T_a9c6b_row0_col0" class="data row0 col0" >91</td>
#       <td id="T_a9c6b_row0_col1" class="data row0 col1" >98</td>
#       <td id="T_a9c6b_row0_col2" class="data row0 col2" >99</td>
#       <td id="T_a9c6b_row0_col3" class="data row0 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row1" class="row_heading level0 row1" >AR</th>
#       <td id="T_a9c6b_row1_col0" class="data row1 col0" >101</td>
#       <td id="T_a9c6b_row1_col1" class="data row1 col1" >90</td>
#       <td id="T_a9c6b_row1_col2" class="data row1 col2" >112</td>
#       <td id="T_a9c6b_row1_col3" class="data row1 col3" >112</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row2" class="row_heading level0 row2" >DE</th>
#       <td id="T_a9c6b_row2_col0" class="data row2 col0" >112</td>
#       <td id="T_a9c6b_row2_col1" class="data row2 col1" >92</td>
#       <td id="T_a9c6b_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_a9c6b_row2_col3" class="data row2 col3" >87</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row3" class="row_heading level0 row3" >FL</th>
#       <td id="T_a9c6b_row3_col0" class="data row3 col0" >83</td>
#       <td id="T_a9c6b_row3_col1" class="data row3 col1" >100</td>
#       <td id="T_a9c6b_row3_col2" class="data row3 col2" >103</td>
#       <td id="T_a9c6b_row3_col3" class="data row3 col3" >98</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row4" class="row_heading level0 row4" >GA</th>
#       <td id="T_a9c6b_row4_col0" class="data row4 col0" >101</td>
#       <td id="T_a9c6b_row4_col1" class="data row4 col1" >99</td>
#       <td id="T_a9c6b_row4_col2" class="data row4 col2" >95</td>
#       <td id="T_a9c6b_row4_col3" class="data row4 col3" >89</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row5" class="row_heading level0 row5" >KY</th>
#       <td id="T_a9c6b_row5_col0" class="data row5 col0" >92</td>
#       <td id="T_a9c6b_row5_col1" class="data row5 col1" >96</td>
#       <td id="T_a9c6b_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_a9c6b_row5_col3" class="data row5 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row6" class="row_heading level0 row6" >LA</th>
#       <td id="T_a9c6b_row6_col0" class="data row6 col0" >98</td>
#       <td id="T_a9c6b_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_a9c6b_row6_col2" class="data row6 col2" >95</td>
#       <td id="T_a9c6b_row6_col3" class="data row6 col3" >97</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row7" class="row_heading level0 row7" >MS</th>
#       <td id="T_a9c6b_row7_col0" class="data row7 col0" >90</td>
#       <td id="T_a9c6b_row7_col1" class="data row7 col1" >103</td>
#       <td id="T_a9c6b_row7_col2" class="data row7 col2" >92</td>
#       <td id="T_a9c6b_row7_col3" class="data row7 col3" >98</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row8" class="row_heading level0 row8" >NC</th>
#       <td id="T_a9c6b_row8_col0" class="data row8 col0" >86</td>
#       <td id="T_a9c6b_row8_col1" class="data row8 col1" >95</td>
#       <td id="T_a9c6b_row8_col2" class="data row8 col2" >109</td>
#       <td id="T_a9c6b_row8_col3" class="data row8 col3" >104</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row9" class="row_heading level0 row9" >OK</th>
#       <td id="T_a9c6b_row9_col0" class="data row9 col0" >100</td>
#       <td id="T_a9c6b_row9_col1" class="data row9 col1" >91</td>
#       <td id="T_a9c6b_row9_col2" class="data row9 col2" >103</td>
#       <td id="T_a9c6b_row9_col3" class="data row9 col3" >114</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row10" class="row_heading level0 row10" >SC</th>
#       <td id="T_a9c6b_row10_col0" class="data row10 col0" >90</td>
#       <td id="T_a9c6b_row10_col1" class="data row10 col1" >101</td>
#       <td id="T_a9c6b_row10_col2" class="data row10 col2" >90</td>
#       <td id="T_a9c6b_row10_col3" class="data row10 col3" >105</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row11" class="row_heading level0 row11" >TN</th>
#       <td id="T_a9c6b_row11_col0" class="data row11 col0" >94</td>
#       <td id="T_a9c6b_row11_col1" class="data row11 col1" >105</td>
#       <td id="T_a9c6b_row11_col2" class="data row11 col2" >102</td>
#       <td id="T_a9c6b_row11_col3" class="data row11 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row12" class="row_heading level0 row12" >TX</th>
#       <td id="T_a9c6b_row12_col0" class="data row12 col0" >104</td>
#       <td id="T_a9c6b_row12_col1" class="data row12 col1" >109</td>
#       <td id="T_a9c6b_row12_col2" class="data row12 col2" >102</td>
#       <td id="T_a9c6b_row12_col3" class="data row12 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row13" class="row_heading level0 row13" >VA</th>
#       <td id="T_a9c6b_row13_col0" class="data row13 col0" >88</td>
#       <td id="T_a9c6b_row13_col1" class="data row13 col1" >97</td>
#       <td id="T_a9c6b_row13_col2" class="data row13 col2" >104</td>
#       <td id="T_a9c6b_row13_col3" class="data row13 col3" >86</td>
#     </tr>
#     <tr>
#       <th id="T_a9c6b_level0_row14" class="row_heading level0 row14" >WV</th>
#       <td id="T_a9c6b_row14_col0" class="data row14 col0" >82</td>
#       <td id="T_a9c6b_row14_col1" class="data row14 col1" >103</td>
#       <td id="T_a9c6b_row14_col2" class="data row14 col2" >114</td>
#       <td id="T_a9c6b_row14_col3" class="data row14 col3" >102</td>
#     </tr>
#   </tbody>
# </table>
# Region: West
# <style type="text/css">
# #T_9bb34_row0_col0, #T_9bb34_row1_col2, #T_9bb34_row2_col2, #T_9bb34_row3_col1, #T_9bb34_row4_col2, #T_9bb34_row5_col1, #T_9bb34_row6_col1, #T_9bb34_row7_col0, #T_9bb34_row8_col2, #T_9bb34_row9_col2, #T_9bb34_row10_col0 {
#   text-align: center;
#   background-color: lightblue;
#   color: white;
# }
# #T_9bb34_row0_col1, #T_9bb34_row0_col2, #T_9bb34_row1_col1, #T_9bb34_row1_col3, #T_9bb34_row2_col0, #T_9bb34_row2_col1, #T_9bb34_row3_col2, #T_9bb34_row3_col3, #T_9bb34_row4_col0, #T_9bb34_row4_col3, #T_9bb34_row5_col0, #T_9bb34_row5_col3, #T_9bb34_row6_col0, #T_9bb34_row6_col3, #T_9bb34_row7_col2, #T_9bb34_row7_col3, #T_9bb34_row8_col1, #T_9bb34_row8_col3, #T_9bb34_row9_col1, #T_9bb34_row9_col3, #T_9bb34_row10_col1, #T_9bb34_row10_col3 {
#   text-align: center;
# }
# #T_9bb34_row0_col3, #T_9bb34_row1_col0, #T_9bb34_row2_col3, #T_9bb34_row3_col0, #T_9bb34_row4_col1, #T_9bb34_row5_col2, #T_9bb34_row6_col2, #T_9bb34_row7_col1, #T_9bb34_row8_col0, #T_9bb34_row9_col0, #T_9bb34_row10_col2 {
#   text-align: center;
#   background-color: lightcoral;
#   color: white;
# }
# </style>
# <table id="T_9bb34" class="dataframe">
#   <caption>Values represent average salary (in thousands $) in West region</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_role</th>
#       <th id="T_9bb34_level0_col0" class="col_heading level0 col0" >Data Analyst</th>
#       <th id="T_9bb34_level0_col1" class="col_heading level0 col1" >Data Engineer</th>
#       <th id="T_9bb34_level0_col2" class="col_heading level0 col2" >Data Scientist</th>
#       <th id="T_9bb34_level0_col3" class="col_heading level0 col3" >Research Scientist</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Job Location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bb34_level0_row0" class="row_heading level0 row0" >AZ</th>
#       <td id="T_9bb34_row0_col0" class="data row0 col0" >103</td>
#       <td id="T_9bb34_row0_col1" class="data row0 col1" >101</td>
#       <td id="T_9bb34_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_9bb34_row0_col3" class="data row0 col3" >88</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row1" class="row_heading level0 row1" >CA</th>
#       <td id="T_9bb34_row1_col0" class="data row1 col0" >90</td>
#       <td id="T_9bb34_row1_col1" class="data row1 col1" >119</td>
#       <td id="T_9bb34_row1_col2" class="data row1 col2" >133</td>
#       <td id="T_9bb34_row1_col3" class="data row1 col3" >97</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row2" class="row_heading level0 row2" >CO</th>
#       <td id="T_9bb34_row2_col0" class="data row2 col0" >102</td>
#       <td id="T_9bb34_row2_col1" class="data row2 col1" >94</td>
#       <td id="T_9bb34_row2_col2" class="data row2 col2" >105</td>
#       <td id="T_9bb34_row2_col3" class="data row2 col3" >77</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row3" class="row_heading level0 row3" >ID</th>
#       <td id="T_9bb34_row3_col0" class="data row3 col0" >94</td>
#       <td id="T_9bb34_row3_col1" class="data row3 col1" >116</td>
#       <td id="T_9bb34_row3_col2" class="data row3 col2" >104</td>
#       <td id="T_9bb34_row3_col3" class="data row3 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row4" class="row_heading level0 row4" >MT</th>
#       <td id="T_9bb34_row4_col0" class="data row4 col0" >95</td>
#       <td id="T_9bb34_row4_col1" class="data row4 col1" >93</td>
#       <td id="T_9bb34_row4_col2" class="data row4 col2" >116</td>
#       <td id="T_9bb34_row4_col3" class="data row4 col3" >93</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row5" class="row_heading level0 row5" >NM</th>
#       <td id="T_9bb34_row5_col0" class="data row5 col0" >100</td>
#       <td id="T_9bb34_row5_col1" class="data row5 col1" >121</td>
#       <td id="T_9bb34_row5_col2" class="data row5 col2" >92</td>
#       <td id="T_9bb34_row5_col3" class="data row5 col3" >98</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row6" class="row_heading level0 row6" >NV</th>
#       <td id="T_9bb34_row6_col0" class="data row6 col0" >94</td>
#       <td id="T_9bb34_row6_col1" class="data row6 col1" >113</td>
#       <td id="T_9bb34_row6_col2" class="data row6 col2" >86</td>
#       <td id="T_9bb34_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row7" class="row_heading level0 row7" >OR</th>
#       <td id="T_9bb34_row7_col0" class="data row7 col0" >106</td>
#       <td id="T_9bb34_row7_col1" class="data row7 col1" >94</td>
#       <td id="T_9bb34_row7_col2" class="data row7 col2" >101</td>
#       <td id="T_9bb34_row7_col3" class="data row7 col3" >105</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row8" class="row_heading level0 row8" >UT</th>
#       <td id="T_9bb34_row8_col0" class="data row8 col0" >90</td>
#       <td id="T_9bb34_row8_col1" class="data row8 col1" >107</td>
#       <td id="T_9bb34_row8_col2" class="data row8 col2" >109</td>
#       <td id="T_9bb34_row8_col3" class="data row8 col3" >94</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row9" class="row_heading level0 row9" >WA</th>
#       <td id="T_9bb34_row9_col0" class="data row9 col0" >89</td>
#       <td id="T_9bb34_row9_col1" class="data row9 col1" >96</td>
#       <td id="T_9bb34_row9_col2" class="data row9 col2" >96</td>
#       <td id="T_9bb34_row9_col3" class="data row9 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_9bb34_level0_row10" class="row_heading level0 row10" >WY</th>
#       <td id="T_9bb34_row10_col0" class="data row10 col0" >110</td>
#       <td id="T_9bb34_row10_col1" class="data row10 col1" >108</td>
#       <td id="T_9bb34_row10_col2" class="data row10 col2" >99</td>
#       <td id="T_9bb34_row10_col3" class="data row10 col3" >104</td>
#     </tr>
#   </tbody>
# </table>
# Region: Northeast
# <style type="text/css">
# #T_2d3d6_row0_col0, #T_2d3d6_row1_col0, #T_2d3d6_row2_col0, #T_2d3d6_row3_col3, #T_2d3d6_row4_col2, #T_2d3d6_row5_col2, #T_2d3d6_row6_col0, #T_2d3d6_row7_col0, #T_2d3d6_row8_col0, #T_2d3d6_row9_col3, #T_2d3d6_row10_col1 {
#   text-align: center;
#   background-color: lightcoral;
#   color: white;
# }
# #T_2d3d6_row0_col1, #T_2d3d6_row0_col2, #T_2d3d6_row1_col1, #T_2d3d6_row1_col3, #T_2d3d6_row2_col1, #T_2d3d6_row2_col2, #T_2d3d6_row3_col0, #T_2d3d6_row3_col1, #T_2d3d6_row4_col0, #T_2d3d6_row4_col1, #T_2d3d6_row5_col1, #T_2d3d6_row5_col3, #T_2d3d6_row6_col1, #T_2d3d6_row6_col2, #T_2d3d6_row7_col1, #T_2d3d6_row7_col3, #T_2d3d6_row8_col1, #T_2d3d6_row8_col3, #T_2d3d6_row9_col0, #T_2d3d6_row9_col1, #T_2d3d6_row10_col0, #T_2d3d6_row10_col3 {
#   text-align: center;
# }
# #T_2d3d6_row0_col3, #T_2d3d6_row1_col2, #T_2d3d6_row2_col3, #T_2d3d6_row3_col2, #T_2d3d6_row4_col3, #T_2d3d6_row5_col0, #T_2d3d6_row6_col3, #T_2d3d6_row7_col2, #T_2d3d6_row8_col2, #T_2d3d6_row9_col2, #T_2d3d6_row10_col2 {
#   text-align: center;
#   background-color: lightblue;
#   color: white;
# }
# </style>
# <table id="T_2d3d6" class="dataframe">
#   <caption>Values represent average salary (in thousands $) in Northeast region</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_role</th>
#       <th id="T_2d3d6_level0_col0" class="col_heading level0 col0" >Data Analyst</th>
#       <th id="T_2d3d6_level0_col1" class="col_heading level0 col1" >Data Engineer</th>
#       <th id="T_2d3d6_level0_col2" class="col_heading level0 col2" >Data Scientist</th>
#       <th id="T_2d3d6_level0_col3" class="col_heading level0 col3" >Research Scientist</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Job Location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d3d6_level0_row0" class="row_heading level0 row0" >CT</th>
#       <td id="T_2d3d6_row0_col0" class="data row0 col0" >89</td>
#       <td id="T_2d3d6_row0_col1" class="data row0 col1" >97</td>
#       <td id="T_2d3d6_row0_col2" class="data row0 col2" >99</td>
#       <td id="T_2d3d6_row0_col3" class="data row0 col3" >106</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row1" class="row_heading level0 row1" >DC</th>
#       <td id="T_2d3d6_row1_col0" class="data row1 col0" >92</td>
#       <td id="T_2d3d6_row1_col1" class="data row1 col1" >101</td>
#       <td id="T_2d3d6_row1_col2" class="data row1 col2" >107</td>
#       <td id="T_2d3d6_row1_col3" class="data row1 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row2" class="row_heading level0 row2" >MA</th>
#       <td id="T_2d3d6_row2_col0" class="data row2 col0" >91</td>
#       <td id="T_2d3d6_row2_col1" class="data row2 col1" >105</td>
#       <td id="T_2d3d6_row2_col2" class="data row2 col2" >101</td>
#       <td id="T_2d3d6_row2_col3" class="data row2 col3" >113</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row3" class="row_heading level0 row3" >MD</th>
#       <td id="T_2d3d6_row3_col0" class="data row3 col0" >93</td>
#       <td id="T_2d3d6_row3_col1" class="data row3 col1" >101</td>
#       <td id="T_2d3d6_row3_col2" class="data row3 col2" >109</td>
#       <td id="T_2d3d6_row3_col3" class="data row3 col3" >88</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row4" class="row_heading level0 row4" >ME</th>
#       <td id="T_2d3d6_row4_col0" class="data row4 col0" >93</td>
#       <td id="T_2d3d6_row4_col1" class="data row4 col1" >93</td>
#       <td id="T_2d3d6_row4_col2" class="data row4 col2" >88</td>
#       <td id="T_2d3d6_row4_col3" class="data row4 col3" >108</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row5" class="row_heading level0 row5" >NH</th>
#       <td id="T_2d3d6_row5_col0" class="data row5 col0" >115</td>
#       <td id="T_2d3d6_row5_col1" class="data row5 col1" >108</td>
#       <td id="T_2d3d6_row5_col2" class="data row5 col2" >97</td>
#       <td id="T_2d3d6_row5_col3" class="data row5 col3" >114</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row6" class="row_heading level0 row6" >NJ</th>
#       <td id="T_2d3d6_row6_col0" class="data row6 col0" >88</td>
#       <td id="T_2d3d6_row6_col1" class="data row6 col1" >92</td>
#       <td id="T_2d3d6_row6_col2" class="data row6 col2" >104</td>
#       <td id="T_2d3d6_row6_col3" class="data row6 col3" >114</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row7" class="row_heading level0 row7" >NY</th>
#       <td id="T_2d3d6_row7_col0" class="data row7 col0" >83</td>
#       <td id="T_2d3d6_row7_col1" class="data row7 col1" >104</td>
#       <td id="T_2d3d6_row7_col2" class="data row7 col2" >112</td>
#       <td id="T_2d3d6_row7_col3" class="data row7 col3" >89</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row8" class="row_heading level0 row8" >PA</th>
#       <td id="T_2d3d6_row8_col0" class="data row8 col0" >84</td>
#       <td id="T_2d3d6_row8_col1" class="data row8 col1" >101</td>
#       <td id="T_2d3d6_row8_col2" class="data row8 col2" >115</td>
#       <td id="T_2d3d6_row8_col3" class="data row8 col3" >94</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row9" class="row_heading level0 row9" >RI</th>
#       <td id="T_2d3d6_row9_col0" class="data row9 col0" >100</td>
#       <td id="T_2d3d6_row9_col1" class="data row9 col1" >100</td>
#       <td id="T_2d3d6_row9_col2" class="data row9 col2" >103</td>
#       <td id="T_2d3d6_row9_col3" class="data row9 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_2d3d6_level0_row10" class="row_heading level0 row10" >VT</th>
#       <td id="T_2d3d6_row10_col0" class="data row10 col0" >103</td>
#       <td id="T_2d3d6_row10_col1" class="data row10 col1" >91</td>
#       <td id="T_2d3d6_row10_col2" class="data row10 col2" >105</td>
#       <td id="T_2d3d6_row10_col3" class="data row10 col3" >102</td>
#     </tr>
#   </tbody>
# </table>
# Region: Midwest
# <style type="text/css">
# #T_91ce2_row0_col0, #T_91ce2_row1_col0, #T_91ce2_row2_col1, #T_91ce2_row3_col2, #T_91ce2_row4_col0, #T_91ce2_row5_col0, #T_91ce2_row6_col0, #T_91ce2_row7_col0, #T_91ce2_row8_col2, #T_91ce2_row9_col1, #T_91ce2_row10_col1, #T_91ce2_row11_col3 {
#   text-align: center;
#   background-color: lightcoral;
#   color: white;
# }
# #T_91ce2_row0_col1, #T_91ce2_row1_col2, #T_91ce2_row2_col2, #T_91ce2_row3_col0, #T_91ce2_row4_col1, #T_91ce2_row5_col1, #T_91ce2_row6_col2, #T_91ce2_row7_col3, #T_91ce2_row8_col0, #T_91ce2_row9_col3, #T_91ce2_row10_col0, #T_91ce2_row11_col2 {
#   text-align: center;
#   background-color: lightblue;
#   color: white;
# }
# #T_91ce2_row0_col2, #T_91ce2_row0_col3, #T_91ce2_row1_col1, #T_91ce2_row1_col3, #T_91ce2_row2_col0, #T_91ce2_row2_col3, #T_91ce2_row3_col1, #T_91ce2_row3_col3, #T_91ce2_row4_col2, #T_91ce2_row4_col3, #T_91ce2_row5_col2, #T_91ce2_row5_col3, #T_91ce2_row6_col1, #T_91ce2_row6_col3, #T_91ce2_row7_col1, #T_91ce2_row7_col2, #T_91ce2_row8_col1, #T_91ce2_row8_col3, #T_91ce2_row9_col0, #T_91ce2_row9_col2, #T_91ce2_row10_col2, #T_91ce2_row10_col3, #T_91ce2_row11_col0, #T_91ce2_row11_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_91ce2" class="dataframe">
#   <caption>Values represent average salary (in thousands $) in Midwest region</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_role</th>
#       <th id="T_91ce2_level0_col0" class="col_heading level0 col0" >Data Analyst</th>
#       <th id="T_91ce2_level0_col1" class="col_heading level0 col1" >Data Engineer</th>
#       <th id="T_91ce2_level0_col2" class="col_heading level0 col2" >Data Scientist</th>
#       <th id="T_91ce2_level0_col3" class="col_heading level0 col3" >Research Scientist</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Job Location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91ce2_level0_row0" class="row_heading level0 row0" >IA</th>
#       <td id="T_91ce2_row0_col0" class="data row0 col0" >81</td>
#       <td id="T_91ce2_row0_col1" class="data row0 col1" >113</td>
#       <td id="T_91ce2_row0_col2" class="data row0 col2" >101</td>
#       <td id="T_91ce2_row0_col3" class="data row0 col3" >104</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row1" class="row_heading level0 row1" >IL</th>
#       <td id="T_91ce2_row1_col0" class="data row1 col0" >79</td>
#       <td id="T_91ce2_row1_col1" class="data row1 col1" >108</td>
#       <td id="T_91ce2_row1_col2" class="data row1 col2" >123</td>
#       <td id="T_91ce2_row1_col3" class="data row1 col3" >92</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row2" class="row_heading level0 row2" >IN</th>
#       <td id="T_91ce2_row2_col0" class="data row2 col0" >90</td>
#       <td id="T_91ce2_row2_col1" class="data row2 col1" >85</td>
#       <td id="T_91ce2_row2_col2" class="data row2 col2" >102</td>
#       <td id="T_91ce2_row2_col3" class="data row2 col3" >98</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row3" class="row_heading level0 row3" >KS</th>
#       <td id="T_91ce2_row3_col0" class="data row3 col0" >102</td>
#       <td id="T_91ce2_row3_col1" class="data row3 col1" >96</td>
#       <td id="T_91ce2_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_91ce2_row3_col3" class="data row3 col3" >101</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row4" class="row_heading level0 row4" >MI</th>
#       <td id="T_91ce2_row4_col0" class="data row4 col0" >101</td>
#       <td id="T_91ce2_row4_col1" class="data row4 col1" >111</td>
#       <td id="T_91ce2_row4_col2" class="data row4 col2" >104</td>
#       <td id="T_91ce2_row4_col3" class="data row4 col3" >105</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row5" class="row_heading level0 row5" >MN</th>
#       <td id="T_91ce2_row5_col0" class="data row5 col0" >93</td>
#       <td id="T_91ce2_row5_col1" class="data row5 col1" >105</td>
#       <td id="T_91ce2_row5_col2" class="data row5 col2" >99</td>
#       <td id="T_91ce2_row5_col3" class="data row5 col3" >97</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row6" class="row_heading level0 row6" >MO</th>
#       <td id="T_91ce2_row6_col0" class="data row6 col0" >95</td>
#       <td id="T_91ce2_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_91ce2_row6_col2" class="data row6 col2" >109</td>
#       <td id="T_91ce2_row6_col3" class="data row6 col3" >107</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row7" class="row_heading level0 row7" >ND</th>
#       <td id="T_91ce2_row7_col0" class="data row7 col0" >90</td>
#       <td id="T_91ce2_row7_col1" class="data row7 col1" >103</td>
#       <td id="T_91ce2_row7_col2" class="data row7 col2" >95</td>
#       <td id="T_91ce2_row7_col3" class="data row7 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row8" class="row_heading level0 row8" >NE</th>
#       <td id="T_91ce2_row8_col0" class="data row8 col0" >97</td>
#       <td id="T_91ce2_row8_col1" class="data row8 col1" >92</td>
#       <td id="T_91ce2_row8_col2" class="data row8 col2" >81</td>
#       <td id="T_91ce2_row8_col3" class="data row8 col3" >83</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row9" class="row_heading level0 row9" >OH</th>
#       <td id="T_91ce2_row9_col0" class="data row9 col0" >88</td>
#       <td id="T_91ce2_row9_col1" class="data row9 col1" >86</td>
#       <td id="T_91ce2_row9_col2" class="data row9 col2" >96</td>
#       <td id="T_91ce2_row9_col3" class="data row9 col3" >101</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row10" class="row_heading level0 row10" >SD</th>
#       <td id="T_91ce2_row10_col0" class="data row10 col0" >121</td>
#       <td id="T_91ce2_row10_col1" class="data row10 col1" >99</td>
#       <td id="T_91ce2_row10_col2" class="data row10 col2" >102</td>
#       <td id="T_91ce2_row10_col3" class="data row10 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_91ce2_level0_row11" class="row_heading level0 row11" >WI</th>
#       <td id="T_91ce2_row11_col0" class="data row11 col0" >89</td>
#       <td id="T_91ce2_row11_col1" class="data row11 col1" >86</td>
#       <td id="T_91ce2_row11_col2" class="data row11 col2" >97</td>
#       <td id="T_91ce2_row11_col3" class="data row11 col3" >83</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a copy of salary_pivot
salary_pivot_df = salary_pivot.copy()

# Add a new column 'max_role_desc' containing the data role with the maximum salary for each state
salary_pivot_df['max_role_desc'] = salary_pivot.idxmax(axis=1)

# Add a new column 'min_role_desc' containing the data role with the minimum salary for each state
salary_pivot_df['min_role_desc'] = salary_pivot.idxmin(axis=1)

# Define a dictionary to map full state names to regions
regions = {
    'AL': 'South',
    'AK': 'West',
    'AZ': 'West',
    'AR': 'South',
    'CA': 'West',
    'CO': 'West',
    'CT': 'Northeast',
    'DE': 'South',
    'FL': 'South',
    'GA': 'South',
    'HI': 'West',
    'ID': 'West',
    'IL': 'Midwest',
    'IN': 'Midwest',
    'IA': 'Midwest',
    'KS': 'Midwest',
    'KY': 'South',
    'LA': 'South',
    'ME': 'Northeast',
    'MD': 'Northeast',
    'MA': 'Northeast',
    'MI': 'Midwest',
    'MN': 'Midwest',
    'MS': 'South',
    'MO': 'Midwest',
    'MT': 'West',
    'NE': 'Midwest',
    'NV': 'West',
    'NH': 'Northeast',
    'NJ': 'Northeast',
    'NM': 'West',
    'NY': 'Northeast',
    'NC': 'South',
    'ND': 'Midwest',
    'OH': 'Midwest',
    'OK': 'South',
    'OR': 'West',
    'PA': 'Northeast',
    'RI': 'Northeast',
    'SC': 'South',
    'SD': 'Midwest',
    'TN': 'South',
    'TX': 'South',
    'UT': 'West',
    'VT': 'Northeast',
    'VA': 'South',
    'WA': 'West',
    'WV': 'South',
    'WI': 'Midwest',
    'WY': 'West',
    'DC': 'Northeast',
}

# Add a new column 'regions' with region values based on the state abbreviations
salary_pivot_df['regions'] = salary_pivot_df.index.map(regions)

# Display the modified DataFrame
salary_pivot_df
# Out:
# data_role     Data Scientist  Data Engineer  Research Scientist  Data Analyst  \
# Job Location
# AL                 99.250000      98.000000           95.625000     90.863636
# AR                111.666667      90.058824          112.333333    100.666667
# AZ                100.281250     100.595238           87.909091    103.222222
# CA                132.539773     118.836735           96.733333     90.466667
# CO                104.764706      94.156250           77.000000    101.595238
# CT                 98.588235      96.533333          105.538462     89.192308
# DC                106.941176     101.357143           96.200000     91.571429
# DE                100.454545      91.611111           86.952381    111.500000
# FL                102.617647      99.604167           98.076923     83.083333
# GA                 95.000000      99.066667           89.307692    100.538462
# IA                101.000000     113.227273          104.090909     81.214286
# ID                104.416667     115.600000           98.666667     93.653846
# IL                123.108108     108.071429           92.400000     79.218750
# IN                101.982143      85.055556           98.071429     89.843750
# KS                 95.117647      95.500000          100.636364    102.000000
# KY                 99.733333      96.333333          100.380952     92.400000
# LA                 95.466667      99.833333           97.269231     97.562500
# MA                101.370690     105.021739          112.790000     91.388889
# MD                109.288462     101.363636           88.000000     92.750000
# ME                 88.000000      93.187500          107.636364     93.071429
# MI                103.681818     110.777778          105.083333    100.823529
# MN                 99.461538     105.181818           97.066667     92.529412
# MO                109.083333      99.750000          107.142857     95.133333
# MS                 91.846154     102.600000           98.000000     90.500000
# MT                116.500000      92.642857           93.333333     94.666667
# NC                109.300000      94.527778          104.052632     86.333333
# ND                 95.200000     103.000000          109.176471     90.333333
# NE                 80.636364      92.454545           82.933333     97.000000
# NH                 96.833333     108.454545          114.000000    115.375000
# NJ                103.931818      91.857143          113.633333     87.911765
# NM                 92.250000     121.181818           98.050000     99.500000
# NV                 86.230769     113.153846          100.222222     94.125000
# NY                111.901961     104.416667           89.272727     82.913793
# OH                 96.100000      85.857143          100.730769     87.700000
# OK                102.846154      91.470588          113.555556     99.666667
# OR                101.406250      93.642857          104.818182    106.181818
# PA                115.100000     100.764706           93.781250     84.269231
# RI                103.250000      99.909091           99.461538    100.000000
# SC                 90.307692     101.363636          104.625000     90.000000
# SD                102.111111      99.272727           99.857143    121.272727
# TN                101.500000     105.184211           99.055556     93.750000
# TX                102.113636     108.852941           81.411765    104.363636
# UT                108.775000     107.000000           94.000000     89.700000
# VA                104.416667      96.571429           85.875000     87.500000
# VT                104.846154      91.200000          102.500000    102.611111
# WA                 96.300000      95.600000           95.576923     88.833333
# WI                 96.638889      85.846154           83.333333     89.403846
# WV                114.230769     103.000000          102.312500     82.000000
# WY                 98.916667     107.578947          104.500000    110.388889
#
# data_role          max_role_desc       min_role_desc    regions
# Job Location
# AL                Data Scientist        Data Analyst      South
# AR            Research Scientist       Data Engineer      South
# AZ                  Data Analyst  Research Scientist       West
# CA                Data Scientist        Data Analyst       West
# CO                Data Scientist  Research Scientist       West
# CT            Research Scientist        Data Analyst  Northeast
# DC                Data Scientist        Data Analyst  Northeast
# DE                  Data Analyst  Research Scientist      South
# FL                Data Scientist        Data Analyst      South
# GA                  Data Analyst  Research Scientist      South
# IA                 Data Engineer        Data Analyst    Midwest
# ID                 Data Engineer        Data Analyst       West
# IL                Data Scientist        Data Analyst    Midwest
# IN                Data Scientist       Data Engineer    Midwest
# KS                  Data Analyst      Data Scientist    Midwest
# KY            Research Scientist        Data Analyst      South
# LA                 Data Engineer      Data Scientist      South
# MA            Research Scientist        Data Analyst  Northeast
# MD                Data Scientist  Research Scientist  Northeast
# ME            Research Scientist      Data Scientist  Northeast
# MI                 Data Engineer        Data Analyst    Midwest
# MN                 Data Engineer        Data Analyst    Midwest
# MO                Data Scientist        Data Analyst    Midwest
# MS                 Data Engineer        Data Analyst      South
# MT                Data Scientist       Data Engineer       West
# NC                Data Scientist        Data Analyst      South
# ND            Research Scientist        Data Analyst    Midwest
# NE                  Data Analyst      Data Scientist    Midwest
# NH                  Data Analyst      Data Scientist  Northeast
# NJ            Research Scientist        Data Analyst  Northeast
# NM                 Data Engineer      Data Scientist       West
# NV                 Data Engineer      Data Scientist       West
# NY                Data Scientist        Data Analyst  Northeast
# OH            Research Scientist       Data Engineer    Midwest
# OK            Research Scientist       Data Engineer      South
# OR                  Data Analyst       Data Engineer       West
# PA                Data Scientist        Data Analyst  Northeast
# RI                Data Scientist  Research Scientist  Northeast
# SC            Research Scientist        Data Analyst      South
# SD                  Data Analyst       Data Engineer    Midwest
# TN                 Data Engineer        Data Analyst      South
# TX                 Data Engineer  Research Scientist      South
# UT                Data Scientist        Data Analyst       West
# VA                Data Scientist  Research Scientist      South
# VT                Data Scientist       Data Engineer  Northeast
# WA                Data Scientist        Data Analyst       West
# WI                Data Scientist  Research Scientist    Midwest
# WV                Data Scientist        Data Analyst      South
# WY                  Data Analyst      Data Scientist       West

# %%
# Calculate unique counts of max_role_desc and min_role_desc
unique_max_role_counts = salary_pivot_df['max_role_desc'].value_counts()
unique_min_role_counts = salary_pivot_df['min_role_desc'].value_counts()

# Create a DataFrame to display the counts
unique_counts_df = pd.DataFrame({
    'Max Role Count': unique_max_role_counts,
    'Min Role Count': unique_min_role_counts
})

# Reset the index to display data role descriptors as a column
unique_counts_df.reset_index(inplace=True)
unique_counts_df.rename(columns={'index': 'Data Role'}, inplace=True)


# Display the unique counts table with a total row
unique_counts_df
# Out:
#             Data Role  Max Role Count  Min Role Count
# 0        Data Analyst               9              24
# 1       Data Engineer              10               8
# 2      Data Scientist              20               8
# 3  Research Scientist              10               9
